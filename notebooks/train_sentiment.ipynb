# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split


df = pd.read_csv("../dataset/sentiment_dataset.csv")
df = df.sample(frac=1).reset_index(drop=True)


train_df, val_df = train_test_split(df, test_size=0.2, stratify=df["label"])

train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)


model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize(batch):
    return tokenizer(batch["text"], padding="max_length", truncation=True, max_length=128)

train_dataset = train_dataset.map(tokenize, batched=True)
val_dataset = val_dataset.map(tokenize, batched=True)

train_dataset = train_dataset.rename_column("label", "labels")
val_dataset = val_dataset.rename_column("label", "labels")

train_dataset.set_format("torch", columns=["input_ids", "attention_mask", "labels"])
val_dataset.set_format("torch", columns=["input_ids", "attention_mask", "labels"])

model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)

training_args = TrainingArguments(
    output_dir="../models/sentiment_model",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    num_train_epochs=4,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    load_best_model_at_end=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

trainer.train()


trainer.save_model("../models/sentiment_model")
tokenizer.save_pretrained("../models/sentiment_model")
# Out:
# Map:   0%|          | 0/48 [00:00<?, ? examples/s]
# Map:   0%|          | 0/12 [00:00<?, ? examples/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\tejas\Desktop\ai_intern\venv\Lib\site-packages\transformers\training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# c:\Users\tejas\Desktop\ai_intern\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 1.0598249435424805, 'eval_runtime': 0.5563, 'eval_samples_per_second': 21.57, 'eval_steps_per_second': 3.595, 'epoch': 1.0}
# c:\Users\tejas\Desktop\ai_intern\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 0.9499230980873108, 'eval_runtime': 0.5621, 'eval_samples_per_second': 21.349, 'eval_steps_per_second': 3.558, 'epoch': 2.0}
# c:\Users\tejas\Desktop\ai_intern\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 0.8208701014518738, 'eval_runtime': 0.5519, 'eval_samples_per_second': 21.745, 'eval_steps_per_second': 3.624, 'epoch': 3.0}
# c:\Users\tejas\Desktop\ai_intern\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 0.7774796485900879, 'eval_runtime': 0.5403, 'eval_samples_per_second': 22.212, 'eval_steps_per_second': 3.702, 'epoch': 4.0}
# {'train_runtime': 41.3708, 'train_samples_per_second': 4.641, 'train_steps_per_second': 0.58, 'train_loss': 0.8891421953837076, 'epoch': 4.0}
# ('../models/sentiment_model\\tokenizer_config.json',
#  '../models/sentiment_model\\special_tokens_map.json',
#  '../models/sentiment_model\\vocab.txt',
#  '../models/sentiment_model\\added_tokens.json',
#  '../models/sentiment_model\\tokenizer.json')
